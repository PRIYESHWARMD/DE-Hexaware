# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading Data in Pandas DataFrame

# %%
data=pd.read_csv('LoanData.csv')
print(data)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %% [markdown]
# # Printing rows of the Data

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# # Printing the column names of the DataFrame

# %%
data.columns.tolist()
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %% [markdown]
# # Summary of Data Frame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# # Descriptive Statistical Measures of a DataFrame

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# # Missing Data Handing

# %%
data.dropna()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# 5               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [480 rows x 13 columns]

# %% [markdown]
# # Sorting DataFrame values

# %%
data.sort_values(by='LoanAmount', ascending=False, inplace=True)
print(data.head())
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 171  LP001585     NaN     Yes         3+  Graduate            No
# 130  LP001469    Male      No          0  Graduate           Yes
# 155  LP001536    Male     Yes         3+  Graduate            No
# 561  LP002813  Female     Yes          1  Graduate           Yes
# 369  LP002191    Male     Yes          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 171            51763                0.0       700.0             300.0
# 130            20166                0.0       650.0             480.0
# 155            39999                0.0       600.0             180.0
# 561            19484                0.0       600.0             360.0
# 369            19730             5266.0       570.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 171             1.0         Urban           Y
# 130             NaN         Urban           Y
# 155             0.0     Semiurban           Y
# 561             1.0     Semiurban           Y
# 369             1.0         Rural           N

# %% [markdown]
# # Merge Data Frames

# %%
data2=data.dropna()
pd.merge(data, data2, on='Loan_ID', how='inner')
# Out:
#       Loan_ID Gender_x Married_x Dependents_x   Education_x Self_Employed_x  \
# 0    LP001536     Male       Yes           3+      Graduate              No
# 1    LP002813   Female       Yes            1      Graduate             Yes
# 2    LP002191     Male       Yes            0      Graduate              No
# 3    LP002547     Male       Yes            1      Graduate              No
# 4    LP002959   Female       Yes            1      Graduate              No
# ..        ...      ...       ...          ...           ...             ...
# 475  LP002792     Male       Yes            1      Graduate              No
# 476  LP001482     Male       Yes            0      Graduate             Yes
# 477  LP001325     Male        No            0  Not Graduate              No
# 478  LP001030     Male       Yes            2      Graduate              No
# 479  LP002840   Female        No            0      Graduate              No
#
#      ApplicantIncome_x  CoapplicantIncome_x  LoanAmount_x  Loan_Amount_Term_x  \
# 0                39999                  0.0         600.0               180.0
# 1                19484                  0.0         600.0               360.0
# 2                19730               5266.0         570.0               360.0
# 3                18333                  0.0         500.0               360.0
# 4                12000                  0.0         496.0               360.0
# ..                 ...                  ...           ...                 ...
# 475               5468               1032.0          26.0               360.0
# 476               3459                  0.0          25.0               120.0
# 477               3620                  0.0          25.0               120.0
# 478               1299               1086.0          17.0               120.0
# 479               2378                  0.0           9.0               360.0
#
#      ...  Dependents_y   Education_y Self_Employed_y ApplicantIncome_y  \
# 0    ...            3+      Graduate              No             39999
# 1    ...             1      Graduate             Yes             19484
# 2    ...             0      Graduate              No             19730
# 3    ...             1      Graduate              No             18333
# 4    ...             1      Graduate              No             12000
# ..   ...           ...           ...             ...               ...
# 475  ...             1      Graduate              No              5468
# 476  ...             0      Graduate             Yes              3459
# 477  ...             0  Not Graduate              No              3620
# 478  ...             2      Graduate              No              1299
# 479  ...             0      Graduate              No              2378
#
#     CoapplicantIncome_y LoanAmount_y Loan_Amount_Term_y Credit_History_y  \
# 0                   0.0        600.0              180.0              0.0
# 1                   0.0        600.0              360.0              1.0
# 2                5266.0        570.0              360.0              1.0
# 3                   0.0        500.0              360.0              1.0
# 4                   0.0        496.0              360.0              1.0
# ..                  ...          ...                ...              ...
# 475              1032.0         26.0              360.0              1.0
# 476                 0.0         25.0              120.0              1.0
# 477                 0.0         25.0              120.0              1.0
# 478              1086.0         17.0              120.0              1.0
# 479                 0.0          9.0              360.0              1.0
#
#      Property_Area_y  Loan_Status_y
# 0          Semiurban              Y
# 1          Semiurban              Y
# 2              Rural              N
# 3              Urban              N
# 4          Semiurban              Y
# ..               ...            ...
# 475        Semiurban              Y
# 476        Semiurban              Y
# 477        Semiurban              Y
# 478            Urban              Y
# 479            Urban              N
#
# [480 rows x 25 columns]

# %% [markdown]
# # Apply Function

# %%
data['outputcolumn'] = data['LoanAmount'].apply(lambda x:x/10)
data.head()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 171  LP001585     NaN     Yes         3+  Graduate            No
# 130  LP001469    Male      No          0  Graduate           Yes
# 155  LP001536    Male     Yes         3+  Graduate            No
# 561  LP002813  Female     Yes          1  Graduate           Yes
# 369  LP002191    Male     Yes          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 171            51763                0.0       700.0             300.0
# 130            20166                0.0       650.0             480.0
# 155            39999                0.0       600.0             180.0
# 561            19484                0.0       600.0             360.0
# 369            19730             5266.0       570.0             360.0
#
#      Credit_History Property_Area Loan_Status  outputcolumn
# 171             1.0         Urban           Y          70.0
# 130             NaN         Urban           Y          65.0
# 155             0.0     Semiurban           Y          60.0
# 561             1.0     Semiurban           Y          60.0
# 369             1.0         Rural           N          57.0

# %% [markdown]
# # By using the lambda operator

# %%
data['appcolumn'] = data['ApplicantIncome'].apply(lambda x:x/10)
data.head()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 171  LP001585     NaN     Yes         3+  Graduate            No
# 130  LP001469    Male      No          0  Graduate           Yes
# 155  LP001536    Male     Yes         3+  Graduate            No
# 561  LP002813  Female     Yes          1  Graduate           Yes
# 369  LP002191    Male     Yes          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 171            51763                0.0       700.0             300.0
# 130            20166                0.0       650.0             480.0
# 155            39999                0.0       600.0             180.0
# 561            19484                0.0       600.0             360.0
# 369            19730             5266.0       570.0             360.0
#
#      Credit_History Property_Area Loan_Status  outputcolumn  appcolumn
# 171             1.0         Urban           Y          70.0     5176.3
# 130             NaN         Urban           Y          65.0     2016.6
# 155             0.0     Semiurban           Y          60.0     3999.9
# 561             1.0     Semiurban           Y          60.0     1948.4
# 369             1.0         Rural           N          57.0     1973.0

# %% [markdown]
# # Visualizing DataFrame

# %%
import matplotlib.pyplot as plt

data['LoanAmount'].hist(bins=20)
plt.title('Loan Amount Distribution')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.show()

# %%
data['Loan_Status'].value_counts().plot(kind='bar', color=['green', 'red'])
plt.title('Loan Status Count')
plt.show()

# %%
import seaborn as sns
import warnings
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15,5)
plt.subplot(1,3,1)
sns.boxplot(data['ApplicantIncome'])
plt.subplot(1,3,2)
sns.boxplot(data['CoapplicantIncome'])
plt.subplot(1,3,3)
sns.boxplot(data['LoanAmount'])
plt.suptitle('Outliers Detection')
plt.show()

# %%
data.plot.scatter(x='ApplicantIncome', y='LoanAmount')
plt.title('Income vs Loan Amount')
plt.show()
